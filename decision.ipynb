# %%
import pandas as pd

data ={
    "email":[
        "Win money now",
        "Hello how are you",
        "Claim your free prize",
        "Meeting at 5pm",
        "Congratulation you won the lottery",
        "Let's catch up today",
        "Free entry in contest",
     "Project discussion today"
     ],

    "label": [1,0,1,0,1,0,1,0]

}

df = pd.DataFrame(data)

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()
X = vectorizer.fit_transform(df["email"])
y = df["label"]

# %%
from  sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)

# %%
from  sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)

# %%
from  sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)

# %%
test_email =["Hello how are you"]

test_vesctor = vectorizer.transform(test_email)

def explain(pred):
  return "spam" if pred == 1 else "not spam"

print("DT:", explain(dt.predict (test_vesctor[0])))
print("RT:", explain(rf.predict (test_vesctor[0])))
print("GB:", explain(gb.predict (test_vesctor[0])))

# %%
print("RF Probability:", rf.predict_proba(test_vesctor))

# %%
print("DT Probability:", dt.predict_proba(test_vesctor))

# %%
print("GB Probability:", gb.predict_proba(test_vesctor))
